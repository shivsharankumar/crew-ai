# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM
llm =LLM(
    model="openai/gpt-4o",
    temperature=0.7
)
llm.call("What is the capital of France?")
# Out:
# 'The capital of France is Paris.'

# %%
from crewai import Agent,Task,Crew
research_agent = Agent(
    role="Research Specialist",
    goal="research interesting facts about the topic: {topic}",
    # goal="Research and analyze data for the team",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)
writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="A highly experienced communication expert skilled in professional writing and summarizing",
    verbose=True,
    llm=llm
)

# %%
task1=Task(
    description="find 3-5 interesting and recent facts about {topic}",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent
)
task2=Task(
    description="Write a 100 word blog post summary about  using the research",
    expected_output="A short blog summary",
    agent=writer_agent,
    context=[task1]
)
crew=Crew(
    agents=[research_agent,writer_agent],
    tasks=[task1,task2],
    verbose=True
)
crew.kickoff(inputs={"topic":"The Future of Electric Vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  85710e19-fb14-45e4-bdd8-dfc9a9c85662                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: find 3-5 interesting and recent facts about The Future of Electric Vehicles                              │
# │  ID: a0b8c99b-1798-43b9-ae23-2086f1ce60f6                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: find 3-5 interesting and recent facts about The Future of Electric Vehicles                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - **Battery Technology Advancements**: Solid-state batteries are expected to significantly impact the future   │
# │  of electric vehicles (EVs). These batteries promise higher energy densities, faster charging times, and        │
# │  improved safety compared to current lithium-ion batteries. Companies like Toyota and QuantumScape are heavily  │
# │  investing in this technology, with commercial production anticipated in the next few years.                    │
# │                                                                                                                 │
# │  - **Global EV Sales Growth**: The global market for electric vehicles is projected to grow substantially,      │
# │  with EVs expected to account for more than 30% of all vehicles sold worldwide by 2030. This growth is driven   │
# │  by increased consumer demand, government incentives, and improvements in charging infrastructure.              │
# │                                                                                                                 │
# │  - **Autonomous Electric Vehicles**: The integration of autonomous driving technology with electric vehicles    │
# │  is poised to revolutionize transportation. Companies like Tesla, Waymo, and GM's Cruise are developing         │
# │  autonomous EVs that could reduce traffic congestion, lower emissions, and provide mobility solutions for       │
# │  those unable to drive.                                                                                         │
# │                                                                                                                 │
# │  - **Charging Infrastructure Expansion**: The expansion of charging infrastructure is critical to the           │
# │  widespread adoption of electric vehicles. Governments and private companies are investing billions in          │
# │  installing fast-charging stations along highways and in urban areas. The European Union, for example, plans    │
# │  to have one million public charging stations by 2025.                                                          │
# │                                                                                                                 │
# │  - **Environmental Impact and Sustainability**: As EVs become more prevalent, there is a growing focus on the   │
# │  sustainability of their production and lifecycle. This includes sourcing raw materials like lithium and        │
# │  cobalt more ethically, recycling batteries, and increasing the use of renewable energy in manufacturing        │
# │  processes to minimize environmental impact.                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  find 3-5 interesting and recent facts about The Future of Electric Vehicles                                    │
# │  Agent:                                                                                                         │
# │  Research Specialist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100 word blog post summary about  using the research                                             │
# │  ID: 3ef7db9e-727c-4e64-98b5-b97cd9e5f2e2                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100 word blog post summary about  using the research                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The rapid advancements in battery technology, particularly the development of solid-state batteries, are set   │
# │  to transform the electric vehicle (EV) industry. These batteries, championed by companies such as Toyota and   │
# │  QuantumScape, offer higher energy densities and faster charging times, promising a leap forward in EV          │
# │  performance and safety. As a result, the global market for EVs is projected to soar, with projections          │
# │  indicating that EVs could make up over 30% of vehicle sales by 2030. This surge is fueled by consumer demand,  │
# │  government incentives, and a significant expansion in charging infrastructure. Autonomous electric vehicles    │
# │  are also on the horizon, with firms like Tesla and Waymo spearheading innovations that could alleviate         │
# │  traffic congestion and lower emissions. Meanwhile, the establishment of extensive charging networks is         │
# │  crucial, with ambitious plans such as the EU's target of one million public charging stations by 2025.         │
# │  Alongside these developments, there is an increasing emphasis on the sustainability of EV production,          │
# │  focusing on ethical sourcing of raw materials, battery recycling, and the integration of renewable energy in   │
# │  manufacturing processes to mitigate environmental impacts.                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Write a 100 word blog post summary about  using the research                                                   │
# │  Agent:                                                                                                         │
# │  Creative Writer                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  85710e19-fb14-45e4-bdd8-dfc9a9c85662                                                                           │
# │  Final Output: The rapid advancements in battery technology, particularly the development of solid-state        │
# │  batteries, are set to transform the electric vehicle (EV) industry. These batteries, championed by companies   │
# │  such as Toyota and QuantumScape, offer higher energy densities and faster charging times, promising a leap     │
# │  forward in EV performance and safety. As a result, the global market for EVs is projected to soar, with        │
# │  projections indicating that EVs could make up over 30% of vehicle sales by 2030. This surge is fueled by       │
# │  consumer demand, government incentives, and a significant expansion in charging infrastructure. Autonomous     │
# │  electric vehicles are also on the horizon, with firms like Tesla and Waymo spearheading innovations that       │
# │  could alleviate traffic congestion and lower emissions. Meanwhile, the establishment of extensive charging     │
# │  networks is crucial, with ambitious plans such as the EU's target of one million public charging stations by   │
# │  2025. Alongside these developments, there is an increasing emphasis on the sustainability of EV production,    │
# │  focusing on ethical sourcing of raw materials, battery recycling, and the integration of renewable energy in   │
# │  manufacturing processes to mitigate environmental impacts.                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw="The rapid advancements in battery technology, particularly the development of solid-state batteries, are set to transform the electric vehicle (EV) industry. These batteries, championed by companies such as Toyota and QuantumScape, offer higher energy densities and faster charging times, promising a leap forward in EV performance and safety. As a result, the global market for EVs is projected to soar, with projections indicating that EVs could make up over 30% of vehicle sales by 2030. This surge is fueled by consumer demand, government incentives, and a significant expansion in charging infrastructure. Autonomous electric vehicles are also on the horizon, with firms like Tesla and Waymo spearheading innovations that could alleviate traffic congestion and lower emissions. Meanwhile, the establishment of extensive charging networks is crucial, with ambitious plans such as the EU's target of one million public charging stations by 2025. Alongside these developments, there is an increasing emphasis on the sustainability of EV production, focusing on ethical sourcing of raw materials, battery recycling, and the integration of renewable energy in manufacturing processes to mitigate environmental impacts.", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='find 3-5 interesting and recent facts about The Future of Electric Vehicles', name='find 3-5 interesting and recent facts about The Future of Electric Vehicles', expected_output='A bullet list of 3-5 facts', summary='find 3-5 interesting and recent facts about The Future of...', raw="- **Battery Technology Advancements**: Solid-state batteries are expected to significantly impact the future of electric vehicles (EVs). These batteries promise higher energy densities, faster charging times, and improved safety compared to current lithium-ion batteries. Companies like Toyota and QuantumScape are heavily investing in this technology, with commercial production anticipated in the next few years.\n\n- **Global EV Sales Growth**: The global market for electric vehicles is projected to grow substantially, with EVs expected to account for more than 30% of all vehicles sold worldwide by 2030. This growth is driven by increased consumer demand, government incentives, and improvements in charging infrastructure.\n\n- **Autonomous Electric Vehicles**: The integration of autonomous driving technology with electric vehicles is poised to revolutionize transportation. Companies like Tesla, Waymo, and GM's Cruise are developing autonomous EVs that could reduce traffic congestion, lower emissions, and provide mobility solutions for those unable to drive.\n\n- **Charging Infrastructure Expansion**: The expansion of charging infrastructure is critical to the widespread adoption of electric vehicles. Governments and private companies are investing billions in installing fast-charging stations along highways and in urban areas. The European Union, for example, plans to have one million public charging stations by 2025.\n\n- **Environmental Impact and Sustainability**: As EVs become more prevalent, there is a growing focus on the sustainability of their production and lifecycle. This includes sourcing raw materials like lithium and cobalt more ethically, recycling batteries, and increasing the use of renewable energy in manufacturing processes to minimize environmental impact.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: research interesting facts about the topic: The Future of Electric Vehicles'}, {'role': 'user', 'content': '\nCurrent Task: find 3-5 interesting and recent facts about The Future of Electric Vehicles\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, no ...
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
